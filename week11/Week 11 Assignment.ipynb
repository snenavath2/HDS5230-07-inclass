# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.0-py3-none-macosx_10_15_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from xgboost) (1.13.1)
# Downloading xgboost-3.0.0-py3-none-macosx_10_15_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.0 MB/s eta 0:00:00 0:00:01
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.0

# %%
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from xgboost import XGBClassifier

# %%
df_data = pd.read_csv('dfdata.csv')

# %%
df_data.head()
# Out:
#    pregnant  glucose  pressure  triceps  insulin  mass  pedigree  age  NA  \
# 0         7      127        72       49       48  40.7     0.721   26   1
# 1         0      105        80       39       87  30.5     0.875   47   0
# 2         8      120        60       12      142  35.9     1.162   22   0
# 3         2       97        70       31      310  26.4     0.138   22   0
# 4         6      123        70       41      215  23.6     0.695   25   0
#
#    outcome
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0

# %%
sample_df = df_data.sample(n=100, random_state=123)
sample_df = sample_df.drop('NA', axis=1)

# %%
sample_df.head()
# Out:
#           pregnant  glucose  pressure  triceps  insulin  mass  pedigree  age  \
# 60483357         1      129        56       18      190  37.7     0.089   21
# 66016672         5      101        76       30       66  39.0     0.509   48
# 23471804         1       95        64       36      270  24.2     0.591   24
# 25194267         4      165        78       34      245  21.8     0.262   59
# 75921350         9      187        78       18      180  38.5     0.167   26
#
#           outcome
# 60483357        0
# 66016672        0
# 23471804        0
# 25194267        1
# 75921350        1

# %%
X = sample_df.drop('outcome', axis=1)
y = sample_df['outcome']

# %%
X
# Out:
#           pregnant  glucose  pressure  triceps  insulin  mass  pedigree  age
# 60483357         1      129        56       18      190  37.7     0.089   21
# 66016672         5      101        76       30       66  39.0     0.509   48
# 23471804         1       95        64       36      270  24.2     0.591   24
# 25194267         4      165        78       34      245  21.8     0.262   59
# 75921350         9      187        78       18      180  38.5     0.167   26
# ...            ...      ...       ...      ...      ...   ...       ...  ...
# 49079760        13       74        58       34      168  26.2     0.646   46
# 34830988         4      189        56       32      168  23.2     0.647   22
# 54703066         1      109        60       18      126  32.8     0.167   24
# 85987967         2      131        70       33      168  59.4     0.514   37
# 87447964         3      111        56       21       36  30.5     0.306   24
#
# [100 rows x 8 columns]

# %%
y
# Out:
# 60483357    0
# 66016672    0
# 23471804    0
# 25194267    1
# 75921350    1
#            ..
# 49079760    0
# 34830988    1
# 54703066    0
# 85987967    1
# 87447964    0
# Name: outcome, Length: 100, dtype: int64

# %%
# Step 2: Take a sample of 100 rows (with seed 123)
sample_df = df_data.sample(n=100, random_state=123)

sample_df = sample_df.drop('NA', axis=1)
# Step 3: Separate features and labels
X = sample_df.drop('outcome', axis=1)
y = sample_df['outcome']

# Step 4: Define XGBoost model
model = XGBClassifier(
    use_label_encoder=False,
    eval_metric='logloss'
)

# Step 6: Measure time and perform CV
start = time.time()

cv_results = cross_val_score(model, X, y, cv=5, scoring='accuracy')

end = time.time()

# Step 7: Report
print("Method used: XGBoost in Python via scikit-learn and 5-fold CV")
print("Dataset size: 100")
print(f"Testing-set predictive performance (Accuracy): {cv_results.mean():.4f}")
print(f"Time taken for the model to be fit (seconds): {round(end - start, 2)}")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [18:40:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [18:40:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [18:40:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [18:40:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Method used: XGBoost in Python via scikit-learn and 5-fold CV
# Dataset size: 100
# Testing-set predictive performance (Accuracy): 0.8700
# Time taken for the model to be fit (seconds): 0.38
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [18:40:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
# Step 2: Take a sample of 1000 rows (with seed 123)
sample_df = df_data.sample(n=1000, random_state=123)

sample_df = sample_df.drop('NA', axis=1)
# Step 3: Separate features and labels
X = sample_df.drop('outcome', axis=1)
y = sample_df['outcome']

# Step 4: Define XGBoost model
model = XGBClassifier(
    use_label_encoder=False,
    eval_metric='logloss'
)

# Step 6: Measure time and perform CV
start = time.time()

cv_results = cross_val_score(model, X, y, cv=5, scoring='accuracy')

end = time.time()

# Step 7: Report
print("Method used: XGBoost in Python via scikit-learn and 5-fold CV")
print("Dataset size: 1000")
print(f"Testing-set predictive performance (Accuracy): {cv_results.mean():.4f}")
print(f"Time taken for the model to be fit (seconds): {round(end - start, 2)}")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [18:46:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [18:46:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [18:46:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Method used: XGBoost in Python via scikit-learn and 5-fold CV
# Dataset size: 1000
# Testing-set predictive performance (Accuracy): 0.9490
# Time taken for the model to be fit (seconds): 0.5
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [18:46:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [18:46:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
# Step 2: Take a sample of 10000 rows (with seed 123)
sample_df = df_data.sample(n=10000, random_state=123)

sample_df = sample_df.drop('NA', axis=1)
# Step 3: Separate features and labels
X = sample_df.drop('outcome', axis=1)
y = sample_df['outcome']

# Step 4: Define XGBoost model
model = XGBClassifier(
    use_label_encoder=False,
    eval_metric='logloss'
)
# Step 6: Measure time and perform CV
start = time.time()

cv_results = cross_val_score(model, X, y, cv=5, scoring='accuracy')

end = time.time()

# Step 7: Report
print("Method used: XGBoost in Python via scikit-learn and 5-fold CV")
print("Dataset size: 10000")
print(f"Testing-set predictive performance (Accuracy): {cv_results.mean():.4f}")
print(f"Time taken for the model to be fit (seconds): {round(end - start, 2)}")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:06:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:06:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:06:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:06:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Method used: XGBoost in Python via scikit-learn and 5-fold CV
# Dataset size: 10000
# Testing-set predictive performance (Accuracy): 0.9746
# Time taken for the model to be fit (seconds): 0.81
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:06:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
# Step 2: Take a sample of 100000 rows (with seed 123)
sample_df = df_data.sample(n=100000, random_state=123)

sample_df = sample_df.drop('NA', axis=1)
# Step 3: Separate features and labels
X = sample_df.drop('outcome', axis=1)
y = sample_df['outcome']

# Step 4: Define XGBoost model
model = XGBClassifier(
    use_label_encoder=False,
    eval_metric='logloss'
)


# Step 6: Measure time and perform CV
start = time.time()

cv_results = cross_val_score(model, X, y, cv=5, scoring='accuracy')

end = time.time()

# Step 7: Report
print("Method used: XGBoost in Python via scikit-learn and 5-fold CV")
print("Dataset size: 100000")
print(f"Testing-set predictive performance (Accuracy): {cv_results.mean():.4f}")
print(f"Time taken for the model to be fit (seconds): {round(end - start, 2)}")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:06:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:06:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:06:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:06:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:06:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Method used: XGBoost in Python via scikit-learn and 5-fold CV
# Dataset size: 100000
# Testing-set predictive performance (Accuracy): 0.9871
# Time taken for the model to be fit (seconds): 5.22

# %%
# Step 2: Take a sample of 1000000 rows (with seed 123)
sample_df = df_data.sample(n=1000000, random_state=123)

sample_df = sample_df.drop('NA', axis=1)
# Step 3: Separate features and labels
X = sample_df.drop('outcome', axis=1)
y = sample_df['outcome']

# Step 4: Define XGBoost model
model = XGBClassifier(
    use_label_encoder=False,
    eval_metric='logloss'
)


# Step 6: Measure time and perform CV
start = time.time()

cv_results = cross_val_score(model, X, y, cv=5, scoring='accuracy')

end = time.time()

# Step 7: Report
print("Method used: XGBoost in Python via scikit-learn and 5-fold CV")
print("Dataset size: 1000000")
print(f"Testing-set predictive performance (Accuracy): {cv_results.mean():.4f}")
print(f"Time taken for the model to be fit (seconds): {round(end - start, 2)}")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:10:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:10:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:10:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:10:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:10:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Method used: XGBoost in Python via scikit-learn and 5-fold CV
# Dataset size: 1000000
# Testing-set predictive performance (Accuracy): 0.9917
# Time taken for the model to be fit (seconds): 27.32

# %%
# Step 2: Take a sample of 10000000 rows (with seed 123)
sample_df = df_data.sample(n=10000000, random_state=123)

sample_df = sample_df.drop('NA', axis=1)
# Step 3: Separate features and labels
X = sample_df.drop('outcome', axis=1)
y = sample_df['outcome']

# Step 4: Define XGBoost model
model = XGBClassifier(
    use_label_encoder=False,
    eval_metric='logloss'
)


# Step 6: Measure time and perform CV
start = time.time()

cv_results = cross_val_score(model, X, y, cv=5, scoring='accuracy')

end = time.time()

# Step 7: Report
print("Method used: XGBoost in Python via scikit-learn and 5-fold CV")
print("Dataset size: 10000000")
print(f"Testing-set predictive performance (Accuracy): {cv_results.mean():.4f}")
print(f"Time taken for the model to be fit (seconds): {round(end - start, 2)}")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:13:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:14:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:15:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:16:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [19:17:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Method used: XGBoost in Python via scikit-learn and 5-fold CV
# Dataset size: 10000000
# Testing-set predictive performance (Accuracy): 0.9931
# Time taken for the model to be fit (seconds): 327.44
